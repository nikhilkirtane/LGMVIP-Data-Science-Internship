# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilkirtane/LGMVIP-Data-Science-Internship/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Beginner Level Task
# 1. Iris Flower Classification ML project

# %% [markdown]
# Importing python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Import the dataset

# %%
col=['Sepal length','Sepal width','Petal length','Petal width','Classlabels']

# %%
nk= pd.read_csv('irisdata.csv', names=col)

# %% [markdown]
# To get first Five records of  dataset use head() function

# %%
nk.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width  Classlabels
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_49['Sepal length'].plot(kind='hist', bins=20, title='Sepal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50['Sepal width'].plot(kind='hist', bins=20, title='Sepal width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_51['Petal length'].plot(kind='hist', bins=20, title='Petal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52.plot(kind='scatter', x='Sepal length', y='Sepal width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53.plot(kind='scatter', x='Sepal width', y='Petal length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Petal width']
#   ys = series['Sepal length']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_54.sort_values('Petal width', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Petal width')
# _ = plt.ylabel('Sepal length')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Petal width']
#   ys = series['Sepal width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_55.sort_values('Petal width', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Petal width')
# _ = plt.ylabel('Sepal width')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Petal width']
#   ys = series['Petal length']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_56.sort_values('Petal width', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Petal width')
# _ = plt.ylabel('Petal length')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Petal width']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Petal width'}, axis=1)
#               .sort_values('Petal width', ascending=True))
#   xs = counted['Petal width']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_57.sort_values('Petal width', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Petal width')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_58['Sepal length'].plot(kind='line', figsize=(8, 4), title='Sepal length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_59['Sepal width'].plot(kind='line', figsize=(8, 4), title='Sepal width')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_60['Petal length'].plot(kind='line', figsize=(8, 4), title='Petal length')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# To get last five records of dataset use tail() function

# %%
nk.tail()
# Out:
#      Sepal length  Sepal width  Petal length  Petal width     Classlabels
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_61['Sepal length'].plot(kind='hist', bins=20, title='Sepal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_62['Sepal width'].plot(kind='hist', bins=20, title='Sepal width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63['Petal length'].plot(kind='hist', bins=20, title='Petal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_64['Petal width'].plot(kind='hist', bins=20, title='Petal width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_65.plot(kind='scatter', x='Sepal length', y='Sepal width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_66.plot(kind='scatter', x='Sepal width', y='Petal length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_67.plot(kind='scatter', x='Petal length', y='Petal width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_68['Sepal length'].plot(kind='line', figsize=(8, 4), title='Sepal length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_69['Sepal width'].plot(kind='line', figsize=(8, 4), title='Sepal width')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_70['Petal length'].plot(kind='line', figsize=(8, 4), title='Petal length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_71['Petal width'].plot(kind='line', figsize=(8, 4), title='Petal width')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
nk.shape
# Out:
# (150, 5)

# %%
nk.describe
# Out:
# <bound method NDFrame.describe of      Sepal length  Sepal width  Petal length  Petal width     Classlabels
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
nk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal length  150 non-null    float64
#  1   Sepal width   150 non-null    float64
#  2   Petal length  150 non-null    float64
#  3   Petal width   150 non-null    float64
#  4   Classlabels   150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# To check null values in dataset

# %%
nk.isnull().sum()
# Out:
# Sepal length    0
# Sepal width     0
# Petal length    0
# Petal width     0
# Classlabels     0
# dtype: int64

# %% [markdown]
# To check datatypes of column

# %%
nk.dtypes
# Out:
# Sepal length    float64
# Sepal width     float64
# Petal length    float64
# Petal width     float64
# Classlabels      object
# dtype: object

# %%
data=nk.groupby('Classlabels')
nk['Classlabels'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
nk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal length  150 non-null    float64
#  1   Sepal width   150 non-null    float64
#  2   Petal length  150 non-null    float64
#  3   Petal width   150 non-null    float64
#  4   Classlabels   150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# To visualize the dataset use seaborn pair plot method

# %%
sns.pairplot(nk,hue='Classlabels')

# %%
sns.heatmap(nk.corr())
# Out:
# <ipython-input-99-9b444ae70f2f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(nk.corr())
# <Axes: >

# %% [markdown]
# Data Preparation

# %%
sp = {'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3}

# %%
nk.Classlabels=[sp[i] for i in nk.Classlabels]

# %%
nk
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Classlabels
# 0             5.1          3.5           1.4          0.2            1
# 1             4.9          3.0           1.4          0.2            1
# 2             4.7          3.2           1.3          0.2            1
# 3             4.6          3.1           1.5          0.2            1
# 4             5.0          3.6           1.4          0.2            1
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3            3
# 146           6.3          2.5           5.0          1.9            3
# 147           6.5          3.0           5.2          2.0            3
# 148           6.2          3.4           5.4          2.3            3
# 149           5.9          3.0           5.1          1.8            3
#
# [150 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# nk['Sepal length'].plot(kind='hist', bins=20, title='Sepal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Sepal width'].plot(kind='hist', bins=20, title='Sepal width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Petal length'].plot(kind='hist', bins=20, title='Petal length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Petal width'].plot(kind='hist', bins=20, title='Petal width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# nk.plot(kind='scatter', x='Sepal length', y='Sepal width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk.plot(kind='scatter', x='Sepal width', y='Petal length', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk.plot(kind='scatter', x='Petal length', y='Petal width', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# nk.plot(kind='scatter', x='Petal width', y='Classlabels', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Classlabels']
#   ys = series['Sepal length']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = nk.sort_values('Classlabels', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Classlabels')
# _ = plt.ylabel('Sepal length')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Classlabels']
#   ys = series['Sepal width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = nk.sort_values('Classlabels', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Classlabels')
# _ = plt.ylabel('Sepal width')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Classlabels']
#   ys = series['Petal length']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = nk.sort_values('Classlabels', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Classlabels')
# _ = plt.ylabel('Petal length')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Classlabels']
#   ys = series['Petal width']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = nk.sort_values('Classlabels', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Classlabels')
# _ = plt.ylabel('Petal width')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# nk['Sepal length'].plot(kind='line', figsize=(8, 4), title='Sepal length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Sepal width'].plot(kind='line', figsize=(8, 4), title='Sepal width')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Petal length'].plot(kind='line', figsize=(8, 4), title='Petal length')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# nk['Petal width'].plot(kind='line', figsize=(8, 4), title='Petal width')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x=nk.iloc[1,0:4]
x
# Out:
# Sepal length    4.9
# Sepal width     3.0
# Petal length    1.4
# Petal width     0.2
# Name: 1, dtype: float64

# %%
y=nk.iloc[0,4]
y
# Out:
# 1

# %% [markdown]
# Split the data to train and test dataset using train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-63a4e7c9ae22> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2557         raise ValueError("At least one array required as input")
#    2558
# -> 2559     arrays = indexable(*arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [4, 150]

# %% [markdown]
# Support Vector Machine Algorithm to
#  Train the dataset using svn.fit() method

# %%
from sklearn.svm import SVC
svn=SVC()
svn.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# Predict from the test dataset

# %%
prediction=svn.predict(x_test)

# %% [markdown]
# Calculating the Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 0.9333333333333333
